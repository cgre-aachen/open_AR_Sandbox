# %% [markdown]
# # 01_MainThread_MarkerDetection
#
# ## Main Thread
#
# This notebook allows you to adapt all features in the Sandbox-envrionment.
#
# Let's start with importing the main modules:
#
# - os-module:
# This module provides a portable way of using operating system dependent functionality. For further information have a look at https://docs.python.org/3/library/os.html
#
# - sys-module:
# This module provides access to some variables used or maintained by the interpreter and to functions that interact strongly with the interpreter. It is always available. For further information have a look at https://docs.python.org/3/library/sys.html

# %%
''' Only use if sandbox is not installed '''

import os,sys
sys.path.append('../../../')

# %% [markdown]
# ## Initialize Sensor and Projector
#
# To know what happens behind the step of initialization the sensor and the projector have a look to the notebooks 'calib_sensor' and 'calib_projector'.

# %%
''' Save the paths to the calibration files '''

from sandbox import _calibration_dir
_calibprojector = _calibration_dir + "my_projector_calibration.json"
_calibsensor = _calibration_dir + "my_sensor_calibration.json"

# %%
''' Import sensor '''

from sandbox.sensor import Sensor
sensor = Sensor(calibsensor=_calibsensor, name="dummy")
# Out:
# c:\users\barbara\open_ar_sandbox\sandbox\sensor\kinectV1.py:7: UserWarning: Freenect module not found, KinectV1 will not work
#   warn('Freenect module not found, KinectV1 will not work')
# dependencies not found for KinectV2 to work. Check installation and try again
# JSON configuration loaded for sensor.
# DummySensor initialized.

# %%
''' Import projector '''

from sandbox.projector import Projector
projector = Projector(calibprojector=_calibprojector)
# Out:
# JSON configuration loaded for projector.
# Projector initialized and server started.
# Please position the browser window accordingly and enter fullscreen!

# %% [markdown]
# ## Initialize marker detection

# %%
''' Initialize the aruco detection '''

from sandbox.markers import MarkerDetection
aruco = MarkerDetection(sensor=sensor)
# Out:
# Using dummy arucos. Create your own aruco positions using .set_aruco_position() functionLaunching server at http://localhost:49440
#
# using dummy aruco module
# Aruco module loaded
# Aruco detection ready

# %% [markdown]
# ## Initialize main thread for live update

# %%
from sandbox.main_thread import MainThread
main = MainThread(sensor=sensor, projector=projector, aruco= aruco if 'aruco' in globals() else None)

# %%
''' Start the thread '''

main.run()
# Out:
# Thread started or resumed...

# %% [markdown]
# ## Control the features of the main thread

# %%
main.widget_plot_module()
# Out:
# Column
#     [0] Markdown(str)
#     [1] Row
#         [0] Column
#             [0] Column
#                 [0] Markdown(str)
#                 [1] Select(name='Choose a colormap', options=['gist_earth', ...], value='gist_earth')
#                 [2] Checkbox(name='Show colormap', value=True)
#             [1] Column
#                 [0] Markdown(str)
#                 [1] Checkbox(name='Show contours', value=True)
#                 [2] IntInput(name='Choose a contour step', value=100, value_throttled=100)
#                 [3] Checkbox(name='Show minor contours', value=True)
#                 [4] IntInput(name='Choose a minor c..., value=50, value_throttled=50)
#                 [5] Checkbox(name='Show contours label', value=True)
#                 [6] IntInput(name='set a contour l..., value=15, value_throttled=15)
#         [1] Column
#             [0] Column
#                 [0] Markdown(str)
#                 [1] Checkbox(name='Aruco Detection', value=True)
# ...

# %% [markdown]
# ## Upload an external DEM to the main thread or fix a frame

# %%
''' Load a frame '''

from sandbox import _test_data 
import numpy as np
file = np.load(_test_data['topo'] + "DEM2.npz")
frame = file['arr_0']

# %%
''' Set the frame static - If frame doesn't change run the function again ''' 

main.load_frame(frame)
# Out:
# loaded

# %%
''' This is also use to set a static frame from the sensor - Again run twice if not changing '''

frame = sensor.get_frame()
main.load_frame(frame)
# Out:
# loaded

# %%
''' If want to stop this completely use frame=None '''

main.load_frame(None)

# %%
#### Stop the thread














main.stop()
# Out:
# Thread stopped.

# %%
sensor.Sensor._stop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-2fc8571a0792> in <module>
# ----> 1 sensor.Sensor._stop()
#
# AttributeError: 'DummySensor' object has no attribute '_stop'
