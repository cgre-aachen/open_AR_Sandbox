# %%
#Only use if sandbox is not installed
import os,sys
sys.path.append('../../')

# %% [markdown]
# ## Initialize Sensor and Projector

# %%
#save the paths to the calibration files 
from sandbox import _calibration_dir
_calibprojector = _calibration_dir + "my_projector_calibration.json"
_calibsensor = _calibration_dir + "my_sensor_calibration.json"

# %%
#Import Sensor
from sandbox.sensor import Sensor
sensor = Sensor(calibsensor=_calibsensor, name="dummy")
# Out:
# JSON configuration loaded for sensor.
# DummySensor initialized.

# %%
# Import projector
from sandbox.projector import Projector
projector = Projector(calibprojector=_calibprojector)
# Out:
# JSON configuration loaded for projector.
# Projector initialized and server started.
# Please position the browser window accordingly and enter fullscreen!
# Launching server at http://localhost:40645

# %% [markdown]
# ## Initialize marker detection

# %%
#Initialize the aruco detection
from sandbox.markers import MarkerDetection
aruco = MarkerDetection(sensor=sensor)
# Out:
# Using dummy arucos. Create your own aruco positions using .set_aruco_position() function
# using dummy aruco module
# Aruco module loaded
# Aruco detection ready

# %% [markdown]
# ## Initialize main thread for live update

# %%
from sandbox.main_thread import MainThread
main = MainThread(sensor=sensor, projector=projector, aruco=aruco)

# %%
# Start the thread 
main.run()
# Out:
# Thread started or resumed...

# %% [markdown]
# ### Control the features of the main thread

# %%
main.widget_plot_module()
# Out:
# Column
#     [0] Markdown(str)
#     [1] Row
#         [0] Column
#             [0] Column
#                 [0] Markdown(str)
#                 [1] Select(name='Choose a colormap', options=['Accent', 'Accent_r', ...], value='gist_earth')
#                 [2] Checkbox(name='Show colormap', value=True)
#             [1] Column
#                 [0] Markdown(str)
#                 [1] Checkbox(name='Show contours', value=True)
#                 [2] IntInput(name='Choose a contour step', value=100, value_throttled=100)
#                 [3] Checkbox(name='Show minor contours', value=True)
#                 [4] IntInput(name='Choose a minor c..., value=50, value_throttled=50)
#                 [5] Checkbox(name='Show contours label', value=True)
#                 [6] IntInput(name='set a contour l..., value=15, value_throttled=15)
#         [1] Column
#             [0] Column
#                 [0] Markdown(str)
#                 [1] Checkbox(name='Aruco Detection', value=True)
#                 [2] Column
#                     [0] Markdown(str)
#                     [1] WidgetBox
#                         [0] Checkbox(name='Show location aruco', value=True)
#                         [1] Checkbox(name='Show aruco id', value=True)
#                         [2] Checkbox(name='Show line connecting a...)
#                         [3] Select(name='Choose a color', options=['aliceblue', ...], value='red')
#             [1] Column
#                 [0] Markdown(str)
#                 [1] RadioButtonGroup(button_type='success', name='Thread controller', options=['Start', 'Stop'], value='Start')
#                 [2] Checkbox(name='Check changes in fame')
#                 [3] CrossSelector(definition_order=False, name='Module manager', options=['CmapModule', ...], value=['CmapModule', ...])
#                 [4] Button(button_type='warning', name='Clear axes from p...)

# %% [markdown]
# ## Import the desired module

# %%
# Import the modules to use and initialize them

# %% [markdown]
# ## Add the module to the main thread

# %%
#main.add_module(name ='Name', module=None)
# Out:
# module Name added to modules
# Traceback (most recent call last):
#   File "c:\users\admin\pycharmprojects\open_ar_sandbox\sandbox\main_thread.py", line 137, in update
#     self.sb_params = self.modules[key].update(self.sb_params)
# AttributeError: 'NoneType' object has no attribute 'update'

# %%
# stop thread of sandbox





main.stop()
# Out:
# thread was not running.

# %%
aruco.set_aruco_position(dict_position={1:[50,30],2:[100,150]}, frame=sensor.get_frame())

# %%
aruco.df_aruco_position
# Out:
#    box_x  box_y  counter  depth_x  depth_y  depth_z  is_inside_box
# 1   50.0   30.0      0.0     50.0     30.0    321.0           True
# 2  100.0  150.0      0.0    100.0    150.0    321.0           True
# /home/danielsk78/GitProjects/open_AR_Sandbox/sandbox/projector/contourlines.py:137: UserWarning: No contour levels were found within the data range.
#   zorder=5
# /home/danielsk78/GitProjects/open_AR_Sandbox/sandbox/projector/contourlines.py:147: UserWarning: No contour levels were found within the data range.
#   zorder=4
