# %% [markdown]
# # 00_CalibModule
#
# ## Projector calibration
#
# This notebook shows the basic steps to set up the projector for the _open AR-Sandbox_.
# This not only involves tweaking of calibration parameters, but also the adjustment of your hardware components, like the motion sensing input device (e.g. Kinect) and the projector.
#
# Let's start with importing the main modules:
#
# - os-module:
# This module provides a portable way of using operating system dependent functionality. For further information have a look at https://docs.python.org/3/library/os.html
#
# - sys-module:
# This module provides access to some variables used or maintained by the interpreter and to functions that interact strongly with the interpreter. It is always available. For further information have a look at https://docs.python.org/3/library/sys.html

# %%
''' Only useful when sandbox is not installed '''

import os,sys
sys.path.append('../../../')

from sandbox import _calibration_dir
from sandbox.projector import Projector

# %%
''' Set use_panel = True will open automatically a panel server ''' 

proj = Projector(use_panel=True)
# Out:
# Projector initialized and server started.
# Please position the browser window accordingly and enter fullscreen!

# %% [markdown]
# The projector creates a matplotlib figure with its corresponding axes.
# This figure can be moved to fit the sandbox projection area.
# We can open the widget now to start calibrating the projector

# %%
widget = proj.calibrate_projector()
widget
# Out:
# Launching server at http://localhost:65497
# Column
#     [0] Markdown(str)
#     [1] IntSlider(end=780, name='Main frame top margin', value=50, value_throttled=50)
#     [2] IntSlider(end=1260, name='Main frame left margin', value=50, value_throttled=50)
#     [3] IntSlider(end=1280, name='Main frame width', start=10, value=700, value_throttled=700)
#     [4] IntSlider(end=800, name='Main frame height', start=10, value=500, value_throttled=500)
#     [5] Markdown(str)
#     [6] TextInput(name='Choose a calibration f..., value='c:\\users\\barbara\\open_...)
#     [7] Button(name='Save calibration')

# %% [markdown]
# Once the projection fits the sandbox we can save the current calibration in a .json file.

# %%
proj.save_json(file = _calibration_dir + 'my_projector_calibration.json')
# Out:
# JSON configuration file saved: c:\users\barbara\open_ar_sandbox\sandbox/../notebooks/calibration_files/my_projector_calibration.json

# %% [markdown]
# Now use the following line to open the calibrated projector

# %%
proj = Projector(calibprojector=_calibration_dir + 'my_projector_calibration.json', use_panel=True)
# Out:
# JSON configuration loaded for projector.
# Projector initialized and server started.
# Please position the browser window accordingly and enter fullscreen!
# Launching server at http://localhost:65505
