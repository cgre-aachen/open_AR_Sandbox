# %%
import os,sys
sys.path.append('../..')
sys.path.append('../../../gempy/')
import gempy as gp
import time

#os.environ["THEANO_FLAGS"] = "mode=FAST_RUN,device=cuda"
os.environ["THEANO_FLAGS"] = "mode=FAST_RUN"
import sandbox.sandbox as sb


#import gempy_sandbox a   s gpsb
import numpy as np
#from PIL import Image, ImageDraw
import pickle

# %%
calibrationdata = sb.CalibrationData(file='my_calibration.json')
sensor = sb.KinectV2(calibrationdata)
projector = sb.Projector(calibrationdata)

# %%
tempfile = 'temp.pickle.pickle'
last_time_modified = os.path.getmtime(tempfile)
geo_model=gp.load_model_pickle(tempfile)

# %%
def update_model(tempfile):
    print('updating model')
    gpsb.stop()
    geo_model = gp.load_model_pickle(tempfile)
    gpsb.geo_model = geo_model
    gpsb.setup()
    gpsb.run()

# %%
gpsb=sb.GemPyModule(geo_model, calibrationdata, sensor, projector)

# %%
gpsb.setup()
# Out:
# Aspect ratio of the model is fixed in XY
# Model size is limited by X dimension
# scale in Model units/ mm (X,Y,Z): [4.0, 4.084249084249084, 2.5]
# the shown extent is [4000.0, 0.0, 0.0, 2775.0]
# the shown extent is [4000.0, 0.0, 0.0, 2775.0]

# %%
gpsb.run()
# Out:
# Thread started or resumed...

# %%
update_model(tempfile)
# Out:
# updating model
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# Thread stopped.
# Aspect ratio of the model is fixed in XY
# Model size is limited by X dimension
# scale in Model units/ mm (X,Y,Z): [4.0, 4.084249084249084, 2.5]
# the shown extent is [4000.0, 0.0, 0.0, 2775.0]
# the shown extent is [4000.0, 0.0, 0.0, 2775.0]
# Thread started or resumed...
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# ...
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0 0]
# a __str__ = [0 1]
# nsle __str__ = 1
# [0 1 2]
# [Erosion, Fault, Erosion]
# Categories (3, object): [Erosion, Onlap, Fault]
# is_erosion [ True False False]
# is_erosion __str__ = [1 0 0]
# b __str__ = [1]
# a __str__ = [0 1]
# nsle __str__ = 1
# is_erosion __str__ = [1 0 0]
# b __str__ = [1 0]
# a __str__ = [0 1]
# nsle __str__ = 1

# %%
gpsb.stop()
